# %%
import scaper
import os
import scaper
import numpy as np

# %%
soundscape_duration = 10.0
audio_dir = '/home/jsondotload/projects/scaper/tests/data/audio'
foreground_folder = os.path.join(audio_dir, 'foreground')
background_folder = os.path.join(audio_dir, 'background')
ref_db = -20

# %%
print("Foreground:")
for x in os.listdir(foreground_folder):
    print("    " + x)
print("\nBackground:")
for x in os.listdir(background_folder):
    print("    " + x)
# Out:
# Foreground:
#     siren
#     human_voice
#     car_horn
#
# Background:
#     street
#     restaurant
#     park

# %%
sc = scaper.Scaper(soundscape_duration,
                   foreground_folder,
                   background_folder)
sc.ref_db = ref_db

# %%
# Add set of backgrounds to be used in each generated examples
sc.add_background(label=('const', 'park'),
                  source_file=('choose', []),
                  source_time=('const', 0))
sc.add_background(label=('const', 'street'),
                  source_file=('choose', []),
                  source_time=('const', 0))

# Add a single type of event to be added to each generated example
sc.add_event(label=('const', 'siren'),
             source_file=('choose', []),
             source_time=('const', 0),
             event_time=('uniform', 0, 9),
             event_duration=('truncnorm', 3, 1, 0.5, 5),
             snr=('normal', 10, 3),
             pitch_shift=('uniform', -2, 2),
             time_stretch=('uniform', 0.8, 1.2))

# Add two more events to be added to each generated example
for _ in range(2):
    sc.add_event(label=('choose', []),
                 source_file=('choose', []),
                 source_time=('const', 0),
                 event_time=('uniform', 0, 9),
                 event_duration=('truncnorm', 3, 1, 0.5, 5),
                 snr=('normal', 10, 3),
                 pitch_shift=None,
                 time_stretch=None)

# %%
audiofile = 'soundscape.wav'
jamsfile = 'soundscape.jams'
txtfile = 'soundscape.txt'
sc.generate(audiofile, jamsfile,
            allow_repeated_label=True,
            allow_repeated_source=True,
            reverb=0.1,
            disable_sox_warnings=True,
            no_audio=False,
            txt_path=txtfile)
# Out:
# /home/jsondotload/projects/scaper/scaper/core.py:1253: ScaperWarning: human_voice event duration (2.80) is greater that source duration (1.00), changing to 1.00
#   ScaperWarning)
# /home/jsondotload/projects/scaper/scaper/core.py:1253: ScaperWarning: car_horn event duration (2.43) is greater that source duration (0.69), changing to 0.69
#   ScaperWarning)

# %%
from IPython.display import Audio, display

# %%
display(Audio(audiofile))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Example: synthesizing 1000 soundscapes in one go


# OUTPUT FOLDER
outfolder = 'audio/soundscapes/'
os.makedirs(outfolder, exist_ok=True)

n_soundscapes = 10
ref_db = -50
duration = 10.0

min_events = 1
max_events = 9

event_time_dist = 'truncnorm'
event_time_mean = 5.0
event_time_std = 2.0
event_time_min = 0.0
event_time_max = 10.0

source_time_dist = 'const'
source_time = 0.0

event_duration_dist = 'uniform'
event_duration_min = 0.5
event_duration_max = 4.0

snr_dist = 'uniform'
snr_min = 6
snr_max = 30

pitch_dist = 'uniform'
pitch_min = -3.0
pitch_max = 3.0

time_stretch_dist = 'uniform'
time_stretch_min = 0.8
time_stretch_max = 1.2

# Generate 1000 soundscapes using a truncated normal distribution of start times

for n in range(n_soundscapes):

    print('Generating soundscape: {:d}/{:d}'.format(n+1, n_soundscapes))

    # create a scaper
    sc = scaper.Scaper(duration, foreground_folder, background_folder)
    sc.protected_labels = []
    sc.ref_db = ref_db

    # add background
    sc.add_background(label=('choose', []),
                      source_file=('choose', []),
                      source_time=('const', 0))

    # add random number of foreground events
    n_events = np.random.randint(min_events, max_events+1)
    for _ in range(n_events):
        sc.add_event(label=('choose', []),
                     source_file=('choose', []),
                     source_time=(source_time_dist, source_time),
                     event_time=(event_time_dist, event_time_mean, event_time_std, event_time_min, event_time_max),
                     event_duration=(event_duration_dist, event_duration_min, event_duration_max),
                     snr=(snr_dist, snr_min, snr_max),
                     pitch_shift=(pitch_dist, pitch_min, pitch_max),
                     time_stretch=(time_stretch_dist, time_stretch_min, time_stretch_max))

    # generate
    audiofile = os.path.join(outfolder, "soundscape_unimodal{:d}.wav".format(n))
    jamsfile = os.path.join(outfolder, "soundscape_unimodal{:d}.jams".format(n))
    txtfile = os.path.join(outfolder, "soundscape_unimodal{:d}.txt".format(n))

    sc.generate(audiofile, jamsfile,
                allow_repeated_label=True,
                allow_repeated_source=False,
                reverb=0.1,
                disable_sox_warnings=True,
                no_audio=False,
                txt_path=txtfile)
# Out:
# Generating soundscape: 1/10
# /home/jsondotload/projects/scaper/scaper/core.py:1253: ScaperWarning: human_voice event duration (2.93) is greater that source duration (0.81), changing to 0.81
#   ScaperWarning)
# Generating soundscape: 2/10
# /home/jsondotload/projects/scaper/scaper/core.py:1253: ScaperWarning: human_voice event duration (2.57) is greater that source duration (0.81), changing to 0.81
#   ScaperWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-b7f974ed2ff0> in <module>
#      77                 disable_sox_warnings=True,
#      78                 no_audio=False,
# ---> 79                 txt_path=txtfile)
#
# ~/projects/scaper/scaper/core.py in generate(self, audio_path, jams_path, allow_repeated_label, allow_repeated_source, reverb, disable_sox_warnings, no_audio, txt_path, txt_sep, disable_instantiation_warnings)
#    1805             allow_repeated_source=allow_repeated_source,
#    1806             reverb=reverb,
# -> 1807             disable_instantiation_warnings=disable_instantiation_warnings)
#    1808         ann = jam.annotations.search(namespace='scaper')[0]
#    1809
#
# ~/projects/scaper/scaper/core.py in _instantiate(self, allow_repeated_label, allow_repeated_source, reverb, disable_instantiation_warnings)
#    1480                 used_labels=fg_labels,
#    1481                 used_source_files=fg_source_files,
# -> 1482                 disable_instantiation_warnings=disable_instantiation_warnings)
#    1483
#    1484             if value.time_stretch is not None:
#
# ~/projects/scaper/scaper/core.py in _instantiate_event(self, event, isbackground, allow_repeated_label, allow_repeated_source, used_labels, used_source_files, disable_instantiation_warnings)
#    1219             else:
#    1220                 while source_file in used_source_files:
# -> 1221                     source_file = _get_value_from_dist(source_file_tuple)
#    1222
#    1223         # Update the used source files list
#
# ~/projects/scaper/scaper/core.py in _get_value_from_dist(dist_tuple)
#     275     # Make sure it's a valid distribution tuple
#     276     _validate_distribution(dist_tuple)
# --> 277     return SUPPORTED_DIST[dist_tuple[0]](*dist_tuple[1:])
#     278
#     279
#
# ~/projects/scaper/scaper/core.py in <lambda>(x)
#      26
#      27 SUPPORTED_DIST = {"const": lambda x: x,
# ---> 28                   "choose": lambda x: random.choice(x),
#      29                   "uniform": random.uniform,
#      30                   "normal": random.normalvariate,
#
# ~/anaconda3/lib/python3.7/random.py in choice(self, seq)
#     257         """Choose a random element from a non-empty sequence."""
#     258         try:
# --> 259             i = self._randbelow(len(seq))
#     260         except ValueError:
#     261             raise IndexError('Cannot choose from an empty sequence') from None
#
# ~/anaconda3/lib/python3.7/random.py in _randbelow(self, n, int, maxsize, type, Method, BuiltinMethod)
#     230         # Only call self.getrandbits if the original random() builtin method
#     231         # has not been overridden or if a new getrandbits() was supplied.
# --> 232         if type(random) is BuiltinMethod or type(getrandbits) is Method:
#     233             k = n.bit_length()  # don't use (n-1) here because n can be 1
#     234             r = getrandbits(k)          # 0 <= r < 2**k
#
# KeyboardInterrupt:

# %%
'/beegfs/work/sonyc/class_predictions/1.0.0/2017'

# %%
audio_dir = '/beegfs/work/sonyc/audio/2017'
cls_dir = ''
